# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from xgboost import XGBClassifier

# %%
train_df = pd.read_csv('../train_test_files/processed_train.csv')

# %%
test_df  = pd.read_csv('../train_test_files/processed_test.csv')

# %%
x=test_df['response_id']
test_df.drop(['response_id'],axis=1,inplace=True)

# %%
model_xg = XGBClassifier( random_state=42)

# %%
# param_grid_xg={
#     'n_estimators': [50, 100, 150],
#     'learning_rate': [0.01, 0.1, 0.2],
#     'max_depth': [3, 4, 5],
#     'subsample': [0.8, 1.0],
#     'colsample_bytree': [0.8, 1.0]
# } 
# 74.405
param_grid_xg = {
    'n_estimators': [100, 200],
    'learning_rate': [0.05, 0.1],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'gamma': [0, 0.1],
    'min_child_weight': [1, 3],
    'reg_alpha': [0, 0.1],
    'reg_lambda': [1, 2]
}
# #74.494

# %%
grid_search = GridSearchCV(
    estimator=model_xg, 
    param_grid=param_grid_xg, 
    scoring='f1',  # or another scoring metric you prefer
    cv=5,                # Number of cross-validation folds
    verbose=2,           # Level of verbosity
    n_jobs=-1            # Use all available cores
)

# %%
grid_search.fit(train_df.drop(['exit_status'],axis=1), train_df['exit_status'])
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.0s
# ...
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=2, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=2, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   3.0s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=42, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 1.0], 'gamma': [0, 0.1],
#                          'learning_rate': [0.05, 0.1], 'max_depth': [3, 5, 7],
#                          'min_child_weight': [1, 3], 'n_estimators': [100, 200],
#                          'reg_alpha': [0, 0.1], 'reg_lambda': [1, 2],
#                          'subsample': [0.8, 1.0]},
#              scoring='f1', verbose=2)

# %%
final = grid_search.predict(test_df)

# %%
predictions = ["Stayed" if pred == 1 else "Left" for pred in final]

# %%
output_df = pd.DataFrame({
    'response_id': x,
    'Predictions': predictions
})

# %%
output_df.to_csv('../output/xgboost_output.csv', index=False)

# %%
print(grid_search.best_params_)
# Out:
# {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}

# %%
y_predict = grid_search.predict(train_df.drop(['exit_status'],axis=1))

# %%
from sklearn.metrics import f1_score
print("the f1 score is :" , f1_score(train_df['exit_status'],y_predict))
# Out:
# the f1 score is : 0.7719805626082423
