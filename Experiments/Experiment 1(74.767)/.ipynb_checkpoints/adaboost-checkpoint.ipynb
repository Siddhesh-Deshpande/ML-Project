# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %%
train_df = pd.read_csv('../processed_files/preprocessed_data.csv')
column_names = train_df.columns

# %%
test_df  = pd.read_csv('../processed_files/preprocessed_test.csv')

# %%
train_df['distance_from_home'].describe()
# Out:
# count    54831.000000
# mean        50.017709
# std         28.530596
# min          1.000000
# 25%         25.000000
# 50%         50.000000
# 75%         75.000000
# max        297.000000
# Name: distance_from_home, dtype: float64

# %%
train_df['leave'] = np.where((train_df['distance_from_home'] > 35) & (train_df['remote_work'] == 0), 1, 0)

# %%
test_df['leave'] = np.where((test_df['distance_from_home'] > 35) & (test_df['remote_work'] == 0), 1, 0)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean = False, with_std = False)

# %%
X = train_df.drop(['exit_status'],axis=1)
Y = train_df['exit_status']

# %%
x=test_df['response_id']
# test_df.drop(['response_id'],axis=1,inplace=True)

# %%
train_df = scaler.fit_transform(train_df)
test_df = scaler.fit_transform(test_df)

# %%
base_estimator = DecisionTreeClassifier()
model = AdaBoostClassifier(estimator=base_estimator,random_state=42)

# %%
param_grid = {
    'n_estimators': [100,200],  # Number of weak learners
    'learning_rate': [1],  # Influence of each estimator
    'estimator__max_depth': [1],  # Max depth of the weak learners (e.g., decision trees)
    'estimator__min_samples_split': [2]  # Minimum samples required to split an internal node (for decision trees)
}

# %%
grid_search = GridSearchCV(
    estimator=model, 
    param_grid=param_grid, 
    scoring='f1',  # or another scoring metric you prefer
    cv=5,                # Number of cross-validation folds
    verbose=2,           # Level of verbosity
    n_jobs=-1            # Use all available cores
)

# %%
grid_search.fit(X, Y)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(),
#                                           random_state=42),
#              n_jobs=-1,
#              param_grid={'estimator__max_depth': [1],
#                          'estimator__min_samples_split': [2],
#                          'learning_rate': [1], 'n_estimators': [100, 200]},
#              scoring='f1', verbose=2)

# %%
final = grid_search.predict(test_df)
# Out:
# /home/siddhesh/notebook/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(

# %%
predictions = ["Stayed" if pred == 1 else "Left" for pred in final]

# %%
output_df = pd.DataFrame({
    'response_id': x,
    'Predictions': predictions
})

# %%
output_df.to_csv('adaboost_output.csv', index=False)

# %%
print(grid_search.best_params_)
# Out:
# {'estimator__max_depth': 1, 'estimator__min_samples_split': 2, 'learning_rate': 1, 'n_estimators': 100}
